# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import glob
#import face_recognition

# %%
jpgfiles = [] 
for file in glob.glob("*.jpg"):
    jpgfiles.append(file)
jpgfiles
# Out:
# ['01-Saanvi.jpg',
#  '02-Shinjan.jpg',
#  '220px-Einstein_tongue.jpg',
#  'engineer-25.jpg']

# %%
from imageai.Prediction.Custom import ModelTraining

model_trainer = ModelTraining()
model_trainer.setModelTypeAsResNet()
model_trainer.setDataDirectory("idenprof")
model_trainer.trainModel(num_objects=10, num_experiments=200, enhance_data=True, batch_size=32, show_network_summary=True)

# %%
from imageai.Prediction.Custom import CustomImagePrediction
import os
from matplotlib import pyplot as plt
import cv2

execution_path = os.getcwd()

prediction = CustomImagePrediction()
prediction.setModelTypeAsResNet()
prediction.setModelPath("idenprof_061-0.7933.h5")
prediction.setJsonPath("idenprof_model_class.json")
prediction.loadModel(num_objects=10)

predictions, probabilities = prediction.predictImage("engineer-25.jpg", result_count=3)

img = cv2.imread("engineer-25.jpg",cv2.IMREAD_COLOR)
imgtest = img.copy()
#imgtest = cv2.cvtColor(imgtest1, cv2.COLOR_BGR2GRAY)
plt.imshow(imgtest)
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# WARNING:tensorflow:From C:\Users\DEEPANJANMAITI\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# engineer  :  85.81445813179016
# pilot  :  8.99873897433281
# farmer  :  4.698340967297554

# %%
predictions, probabilities = prediction.predictImage("01-Saanvi.jpg", result_count=5)

img = cv2.imread("01-Saanvi.jpg",cv2.IMREAD_COLOR)
imgtest = img.copy()
#imgtest = cv2.cvtColor(imgtest1, cv2.COLOR_BGR2GRAY)
plt.imshow(imgtest)
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# doctor  :  51.49312615394592
# pilot  :  46.265652775764465
# farmer  :  1.6886312514543533
# police  :  0.4757351242005825
# engineer  :  0.05209014634601772

# %%
predictions, probabilities = prediction.predictImage("02-Shinjan.jpg", result_count=3)

img = cv2.imread("02-Shinjan.jpg",cv2.IMREAD_COLOR)
imgtest = img.copy()
#imgtest = cv2.cvtColor(imgtest1, cv2.COLOR_BGR2GRAY)
plt.imshow(imgtest)
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# farmer  :  99.99145269393921
# police  :  0.00785595111665316
# firefighter  :  0.00036882429412798956

# %%
predictions, probabilities = prediction.predictImage("220px-Einstein_tongue.jpg", result_count=3)

img = cv2.imread("220px-Einstein_tongue.jpg",cv2.IMREAD_COLOR)
imgtest = img.copy()
#imgtest = cv2.cvtColor(imgtest1, cv2.COLOR_BGR2GRAY)
plt.imshow(imgtest)
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# waiter  :  94.82008814811707
# pilot  :  1.3590570539236069
# engineer  :  1.2407727539539337
